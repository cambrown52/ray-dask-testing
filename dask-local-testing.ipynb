# %% [markdown]
# # Parallel Execution of a Long-Running Function with Dask
#
# This notebook demonstrates how to define a long-running function and run it multiple times in parallel using Dask.

# %%
from dask.distributed import Client, LocalCluster
import time

# Start a local Dask cluster

cluster = LocalCluster(n_workers=6, threads_per_worker=1, memory_limit='4GB')
client = Client(cluster)
client
# Out:
# <Client: 'tcp://127.0.0.1:53950' processes=6 threads=6, memory=22.35 GiB>
# 2025-06-12 12:37:18,437 - distributed.dashboard.components.shared - ERROR - list index out of range
# Traceback (most recent call last):
#   File "c:\sourcerepos\ray-dask-testing\.venv\Lib\site-packages\distributed\utils.py", line 824, in wrapper
#     return func(*args, **kwargs)
#   File "c:\sourcerepos\ray-dask-testing\.venv\Lib\site-packages\distributed\dashboard\components\shared.py", line 206, in cb
#     data = profile.plot_data(self.states[new[0]], profile_interval)
#                              ~~~~~~~~~~~^^^^^^^^
# IndexError: list index out of range
# 2025-06-12 12:37:18,459 - bokeh.server.protocol_handler - ERROR - error handling message
#  message: Message 'PATCH-DOC' content: {'events': [{'kind': 'ModelChanged', 'model': {'id': 'p1951'}, 'attr': 'indices', 'new': [8]}]}
#  error: IndexError('list index out of range')
# Traceback (most recent call last):
#   File "c:\sourcerepos\ray-dask-testing\.venv\Lib\site-packages\bokeh\server\protocol_handler.py", line 94, in handle
#     work = await handler(message, connection)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\sourcerepos\ray-dask-testing\.venv\Lib\site-packages\bokeh\server\session.py", line 94, in _needs_document_lock_wrapper
#     result = func(self, *args, **kwargs)
#   File "c:\sourcerepos\ray-dask-testing\.venv\Lib\site-packages\bokeh\server\session.py", line 286, in _handle_patch
#     message.apply_to_document(self.document, self)
#     ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^
#   File "c:\sourcerepos\ray-dask-testing\.venv\Lib\site-packages\bokeh\protocol\messages\patch_doc.py", line 104, in apply_to_document
#     invoke_with_curdoc(doc, lambda: doc.apply_json_patch(self.payload, setter=setter))
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\sourcerepos\ray-dask-testing\.venv\Lib\site-packages\bokeh\document\callbacks.py", line 453, in invoke_with_curdoc
#     return f()
#   File "c:\sourcerepos\ray-dask-testing\.venv\Lib\site-packages\bokeh\protocol\messages\patch_doc.py", line 104, in <lambda>
#     invoke_with_curdoc(doc, lambda: doc.apply_json_patch(self.payload, setter=setter))
#                                     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\sourcerepos\ray-dask-testing\.venv\Lib\site-packages\bokeh\document\document.py", line 391, in apply_json_patch
#     DocumentPatchedEvent.handle_event(self, event, setter)
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^
#   File "c:\sourcerepos\ray-dask-testing\.venv\Lib\site-packages\bokeh\document\events.py", line 244, in handle_event
#     event_cls._handle_event(doc, event)
#     ~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
#   File "c:\sourcerepos\ray-dask-testing\.venv\Lib\site-packages\bokeh\document\events.py", line 376, in _handle_event
#     model.set_from_json(attr, value, setter=event.setter)
#     ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\sourcerepos\ray-dask-testing\.venv\Lib\site-packages\bokeh\core\has_props.py", line 448, in set_from_json
#     descriptor.set_from_json(self, value, setter=setter)
#     ~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\sourcerepos\ray-dask-testing\.venv\Lib\site-packages\bokeh\core\property\descriptors.py", line 420, in set_from_json
#     self._set(obj, old, value, setter=setter)
#     ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\sourcerepos\ray-dask-testing\.venv\Lib\site-packages\bokeh\core\property\descriptors.py", line 614, in _set
#     self._trigger(obj, old, value, hint=hint, setter=setter)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\sourcerepos\ray-dask-testing\.venv\Lib\site-packages\bokeh\core\property\descriptors.py", line 692, in _trigger
#     obj.trigger(self.name, old, value, hint, setter)
#     ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\sourcerepos\ray-dask-testing\.venv\Lib\site-packages\bokeh\model\model.py", line 583, in trigger
#     super().trigger(descriptor.name, old, new, hint=hint, setter=setter)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\sourcerepos\ray-dask-testing\.venv\Lib\site-packages\bokeh\util\callback_manager.py", line 177, in trigger
#     self.document.callbacks.notify_change(cast(Model, self), attr, old, new, hint, setter, invoke)
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\sourcerepos\ray-dask-testing\.venv\Lib\site-packages\bokeh\document\callbacks.py", line 251, in notify_change
#     self.trigger_on_change(event)
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^
#   File "c:\sourcerepos\ray-dask-testing\.venv\Lib\site-packages\bokeh\document\callbacks.py", line 418, in trigger_on_change
#     invoke_with_curdoc(doc, event.callback_invoker)
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\sourcerepos\ray-dask-testing\.venv\Lib\site-packages\bokeh\document\callbacks.py", line 453, in invoke_with_curdoc
#     return f()
#   File "c:\sourcerepos\ray-dask-testing\.venv\Lib\site-packages\bokeh\util\callback_manager.py", line 174, in invoke
#     callback(attr, old, new)
#     ~~~~~~~~^^^^^^^^^^^^^^^^
#   File "c:\sourcerepos\ray-dask-testing\.venv\Lib\site-packages\bokeh\core\property\validation.py", line 95, in func
#     return input_function(*args, **kwargs)
#   File "c:\sourcerepos\ray-dask-testing\.venv\Lib\site-packages\distributed\utils.py", line 824, in wrapper
#     return func(*args, **kwargs)
#   File "c:\sourcerepos\ray-dask-testing\.venv\Lib\site-packages\distributed\dashboard\components\shared.py", line 206, in cb
#     data = profile.plot_data(self.states[new[0]], profile_interval)
#                              ~~~~~~~~~~~^^^^^^^^
# IndexError: list index out of range

# %%
# Define a long-running function
def long_running_task(x):
    print(f"Starting task {x}")
    time.sleep(30)  # Simulate a long computation
    print(f"Finished task {x}")
    return x * x

# %%
from dask import delayed

# Wrap the function calls with dask.delayed
tasks = [delayed(long_running_task)(i) for i in range(100)]

# %%
100*30/60/14
# Out:
# 3.5714285714285716

# %%
# Compute the results in parallel
results = client.compute(tasks, sync=True)
results
# Out:
# [0,
#  1,
#  4,
#  9,
#  16,
#  25,
#  36,
#  49,
#  64,
#  81,
#  100,
#  121,
#  144,
#  169,
#  196,
#  225,
#  256,
#  289,
#  324,
#  361,
#  400,
#  441,
#  484,
#  529,
#  576,
#  625,
#  676,
#  729,
#  784,
#  841,
#  900,
#  961,
#  1024,
#  1089,
#  1156,
#  1225,
#  1296,
#  1369,
#  1444,
#  1521,
#  1600,
#  1681,
#  1764,
#  1849,
#  1936,
#  2025,
#  2116,
#  2209,
#  2304,
#  2401,
#  2500,
#  2601,
#  2704,
#  2809,
#  2916,
#  3025,
#  3136,
#  3249,
#  3364,
#  3481,
#  3600,
#  3721,
#  3844,
#  3969,
#  4096,
#  4225,
#  4356,
#  4489,
#  4624,
#  4761,
#  4900,
#  5041,
#  5184,
#  5329,
#  5476,
#  5625,
#  5776,
#  5929,
#  6084,
#  6241,
#  6400,
#  6561,
#  6724,
#  6889,
#  7056,
#  7225,
#  7396,
#  7569,
#  7744,
#  7921,
#  8100,
#  8281,
#  8464,
#  8649,
#  8836,
#  9025,
#  9216,
#  9409,
#  9604,
#  9801]

# %%
# Compute the results in parallel
results = client.compute(tasks, sync=False)
results
# Out:
# [<Future: pending, key: long_running_task-fbed9550-cf85-4cbd-b02b-f44e8611eebe>,
#  <Future: pending, key: long_running_task-953eb39b-8e28-4016-bc00-e15b3c9cf4ea>,
#  <Future: pending, key: long_running_task-98980f85-baa9-4fa5-b38d-9abe8dccc244>,
#  <Future: pending, key: long_running_task-fe6d59b1-5511-4819-8b4c-77a086ffbe0f>,
#  <Future: pending, key: long_running_task-311a728e-2a9c-40cb-829a-e455e1cd62b5>,
#  <Future: pending, key: long_running_task-077f9bbe-d1cd-4b8c-a7b8-ef70d9381a07>,
#  <Future: pending, key: long_running_task-8e3cc515-a6b7-404c-9a34-0c792db4e477>,
#  <Future: pending, key: long_running_task-192c5c8d-a5ea-4c43-bc0e-fa3d88134c23>,
#  <Future: pending, key: long_running_task-7b8edaf2-3d5b-45f5-b4ec-3c5f21b0b3c6>,
#  <Future: pending, key: long_running_task-38a61206-60ff-4725-acaf-bd2adb77a7bf>,
#  <Future: pending, key: long_running_task-57904034-0e1b-417b-b815-d8720592ac60>,
#  <Future: pending, key: long_running_task-8d59aaa7-f697-4576-a34c-78f99974788f>,
#  <Future: pending, key: long_running_task-b9024f6a-3614-45a4-b9c0-4a72967e6ed9>,
#  <Future: pending, key: long_running_task-13fbf118-f2a1-45e0-804e-dbc63581a799>,
#  <Future: pending, key: long_running_task-ea30735d-68cc-47e7-a05c-9e2cb020daff>,
#  <Future: pending, key: long_running_task-058378d7-8910-475d-b4c9-37056f5ad5e4>,
#  <Future: pending, key: long_running_task-fdab7a9e-e09d-4927-aa99-8c8bdca832d5>,
#  <Future: pending, key: long_running_task-605f97b5-0049-4520-ba9a-a7eab3d0b6e5>,
#  <Future: pending, key: long_running_task-fcde2a1d-3933-4322-8a1f-f04047641790>,
#  <Future: pending, key: long_running_task-e8b3698f-ebac-4b05-aed0-75cff68ea9e1>,
#  <Future: pending, key: long_running_task-e941abb2-dbed-41c7-ad4a-2716d0463c76>,
#  <Future: pending, key: long_running_task-8874d090-0c16-4fbe-814f-dd93fabf7131>,
#  <Future: pending, key: long_running_task-676e3ff1-ccaa-4917-89f8-4b1026b3045b>,
#  <Future: pending, key: long_running_task-5924d1e6-f209-4dab-b713-6f387d2a0975>,
#  <Future: pending, key: long_running_task-e9f5ccc8-d8c3-492b-ba7b-9399afb15e0e>,
#  <Future: pending, key: long_running_task-d111a64f-45db-43e4-b396-3b1d44e54850>,
#  <Future: pending, key: long_running_task-438ce454-4b07-4a23-b70e-531ef18d8571>,
#  <Future: pending, key: long_running_task-36fddb42-74dd-4800-a63e-39bcf355d364>,
#  <Future: pending, key: long_running_task-bb821bee-f3bb-4783-acde-3bf91abb0e94>,
#  <Future: pending, key: long_running_task-bdb505fc-0987-4d60-8619-2227111e3a34>,
#  <Future: pending, key: long_running_task-6ac8b10f-968c-4eb9-b9a8-c0aaba6975dc>,
#  <Future: pending, key: long_running_task-f76669c5-d266-4691-b17a-45f332633b10>,
#  <Future: pending, key: long_running_task-564a42c8-9fe4-425c-93aa-57ec2f8c6498>,
#  <Future: pending, key: long_running_task-ce65a8b4-5acb-4bc2-b242-9b581c6b43f0>,
#  <Future: pending, key: long_running_task-31c102aa-7c4c-41da-8366-73266ed59411>,
#  <Future: pending, key: long_running_task-66ddcfb3-afd2-48af-8d49-5cfe55f51c1c>,
#  <Future: pending, key: long_running_task-96c9e88c-408c-47de-a1ec-ba7cedaf32e3>,
#  <Future: pending, key: long_running_task-3e3ac3d4-fc19-4c56-abb7-dfdb104913f2>,
#  <Future: pending, key: long_running_task-279fe79b-6e84-4f83-b5cc-6b37056d6bc2>,
#  <Future: pending, key: long_running_task-addc86bd-b43b-440f-9fea-6462e56f48c9>,
#  <Future: pending, key: long_running_task-cc669c03-5a65-4a57-9a45-f23f1ae3dff7>,
#  <Future: pending, key: long_running_task-a30f0426-319f-46df-946c-bc8ffed18ba5>,
#  <Future: pending, key: long_running_task-fe2bff3e-1f4d-4e43-bc86-b7e50c7fda0a>,
#  <Future: pending, key: long_running_task-5575f492-cdb6-4c5e-ae50-7a585ba5a2dc>,
#  <Future: pending, key: long_running_task-4937033e-ad79-47df-92d3-08baa9b40fe7>,
#  <Future: pending, key: long_running_task-dbcebbd8-ab5c-49eb-a643-2e6d3b2036fa>,
#  <Future: pending, key: long_running_task-4d6d4959-9e48-4064-98dc-b3a907e60ba5>,
#  <Future: pending, key: long_running_task-2e9b3063-97a4-4465-8cd1-64e43214803c>,
#  <Future: pending, key: long_running_task-7722fd16-a757-4ad8-a010-ddb5edf7a174>,
#  <Future: pending, key: long_running_task-7e61bd8b-ed71-451b-ba29-4b1ee606e0de>,
#  <Future: pending, key: long_running_task-829797bc-bbd5-4efe-b2bb-eeee8739859c>,
#  <Future: pending, key: long_running_task-8b8d038c-e0ea-4978-9dec-4ffe93a0bf3e>,
#  <Future: pending, key: long_running_task-62b27e05-cee3-4967-a29e-40f961a7b0dd>,
#  <Future: pending, key: long_running_task-fb8d67b5-cc57-4cea-9683-31871fabdac6>,
#  <Future: pending, key: long_running_task-fc585dbb-e232-4243-9f6d-739ad2d0050a>,
#  <Future: pending, key: long_running_task-e3f862a5-5dc4-4507-a26a-df056e9d9132>,
#  <Future: pending, key: long_running_task-8b9d6cf3-e04a-4f16-9407-fcab6b3fc043>,
#  <Future: pending, key: long_running_task-60fc44a4-66d9-4ba6-a2a4-4137f31632cf>,
#  <Future: pending, key: long_running_task-b281ff61-a368-4b14-b43a-674800fee351>,
#  <Future: pending, key: long_running_task-1a985dbb-35e1-4df8-91b1-db0ad3a35265>,
#  <Future: pending, key: long_running_task-a33e8e5e-c991-46a2-959a-6da9fcd4ced6>,
#  <Future: pending, key: long_running_task-4a526e2c-2f3c-4cba-b68c-65febaa7f441>,
#  <Future: pending, key: long_running_task-b7c5583d-68a6-46e3-96e9-cef5e54cc612>,
#  <Future: pending, key: long_running_task-eb62657b-ff86-4f0c-8955-e71a8ea1058a>,
#  <Future: pending, key: long_running_task-96df3f1d-fba2-4be4-ab2b-b1f49fb15389>,
#  <Future: pending, key: long_running_task-b56ec721-7671-4c8d-913d-c5c0287daa6c>,
#  <Future: pending, key: long_running_task-42b3ff2a-b69e-4af6-8b7f-d74d5d3a8040>,
#  <Future: pending, key: long_running_task-82b4a2b2-40dd-4af5-b03c-baacbdbeff64>,
#  <Future: pending, key: long_running_task-32dbfbdc-f85f-4021-9924-59f7374c6c86>,
#  <Future: pending, key: long_running_task-c6c02a81-be36-4a39-8947-755551f97f5e>,
#  <Future: pending, key: long_running_task-1d04cc63-7673-4795-8782-29eaf67e168e>,
#  <Future: pending, key: long_running_task-d174e061-1769-4712-99e7-0c2fec0a273b>,
#  <Future: pending, key: long_running_task-d4b7c40b-2ea3-4535-b7bd-ebdd592b0802>,
#  <Future: pending, key: long_running_task-cbb6bc80-4ee8-40ca-b981-0c51dcfe343e>,
#  <Future: pending, key: long_running_task-246f5d95-2d6a-4466-a445-73063ce1cd08>,
#  <Future: pending, key: long_running_task-98dda3f4-e6ee-4f79-86cb-cda6d3693654>,
#  <Future: pending, key: long_running_task-4526fe54-1872-4350-beaf-df74df46b9eb>,
#  <Future: pending, key: long_running_task-38bc74e8-666f-4ad0-8089-300e4c153235>,
#  <Future: pending, key: long_running_task-cce70544-6fb9-43f2-aaad-327f2ee6e61f>,
#  <Future: pending, key: long_running_task-b4a1f248-d8d5-47b0-8c20-28223f3ba14e>,
#  <Future: pending, key: long_running_task-f19162f4-0a67-41e3-9548-e445a97e4d55>,
#  <Future: pending, key: long_running_task-a42de325-77bc-4a22-9317-2dae29bea82f>,
#  <Future: pending, key: long_running_task-998e9ae5-a57d-480f-9bbf-4131c1a72bdf>,
#  <Future: pending, key: long_running_task-f9f31d8a-e5d0-442d-9d08-8f0b0313bc6c>,
#  <Future: pending, key: long_running_task-bd6722d7-8a75-4206-80d7-dfee69560a4b>,
#  <Future: pending, key: long_running_task-87cb4749-c9d1-4443-9c37-98b6b32305d0>,
#  <Future: pending, key: long_running_task-73974f75-956d-4578-b6eb-a5feb31b34fb>,
#  <Future: pending, key: long_running_task-d23d5f0e-f4d8-440b-b5f6-3e7d4de68f02>,
#  <Future: pending, key: long_running_task-1d347c5e-d4f2-4cff-aad9-f4315a857de4>,
#  <Future: pending, key: long_running_task-4e5d6451-d682-4ae7-aace-a3a7dcb9377a>,
#  <Future: pending, key: long_running_task-1fd95805-93ab-4b97-8033-c779da5bfbbe>,
#  <Future: pending, key: long_running_task-e2f579eb-8f98-42cd-b542-2d65c4a3e4af>,
#  <Future: pending, key: long_running_task-db1833e9-f583-4f2e-a7a6-e301075844b1>,
#  <Future: pending, key: long_running_task-75f3b3ed-9d0a-429f-b56d-9cd9776b96d6>,
#  <Future: pending, key: long_running_task-f63a207b-3a31-4f49-b053-f8dcf223515d>,
#  <Future: pending, key: long_running_task-85ae98cf-0440-4550-97cc-ca7ab219b87d>,
#  <Future: pending, key: long_running_task-f96fd55a-6eb3-434c-93a4-448306a1acfa>,
#  <Future: pending, key: long_running_task-0135821c-64aa-4d00-bf32-126ecca7ddd5>,
#  <Future: pending, key: long_running_task-9d31f68f-4bfb-4f8f-ab90-0571057d396f>,
#  <Future: pending, key: long_running_task-a105472d-4887-4856-9522-7700b29fac76>]

# %%
# Optionally, close the client when done
client.close()
